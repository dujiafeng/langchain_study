# %% [markdown]
# # 03 - Deep Agents 发布日志
#
# **来源:** [LangChain Docs - Changelog](https://docs.langchain.com/oss/python/deepagents/changelog-py)
#
# 请查阅官方文档获取最新版本更新说明。

# %% [markdown]
# ---
# **参考链接**
#
# - [Changelog - LangChain Docs](https://docs.langchain.com/oss/python/deepagents/changelog-py)
# - [Documentation Index](https://docs.langchain.com/llms.txt)
